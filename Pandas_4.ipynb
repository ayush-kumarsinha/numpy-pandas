# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush-kumarsinha/numpy-pandas/blob/main/Pandas_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop('PassengerId', axis=1,inplace=True)  # drop() is used to remove rows or columns from a DataFrame.
# inplace=True → means the change will be applied directly to df (it won’t return a new DataFrame, it updates the existing one).

# %%
df.drop(3,inplace=True)   # 3 → means you want to drop the row with index label = 3.

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# each value in the Name column will become the row label (index).


# This means the change will be applied directly to the same DataFrame (df) without creating a new one.

# If you don’t use inplace=True, then you’d have to assign it back:

# colunm ko haat kar ke index ke place pe name ka value rakha jata hai

df.set_index("Name", inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)  # again index 0, 1, 2, 3...... se hi start hoga

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {'key1' :[3,4,5,6,7],
     'key2' :[5,6,7,8,6],
     'key3' :[4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()  #dropna() removes all the rows that contain NaN (missing values) from the DataFrame.

# By default → if any column in a row has NaN, that row will be dropped.
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(inplace=True)   # inplace=True means 👉 the change will be applied directly on df1, not creating a new DataFrame.

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)   #axis=1 means 👉 check for columns (not rows).
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2 = pd.read_csv('taxonomy.csv')

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2.fillna("ayush")  # Nan ke place pe ayush fill karo
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency     ayush                 ayush
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.reset_index(inplace=True)
# reset_index() puts the current index back into a normal column and restores the default index (0,1,2,...).

# inplace=True means 👉 the change is applied directly to df (no new DataFrame is returned).

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#            index                                               Name  Pclass  \
# Survived
# 0         244315  Braund, Mr. Owen HarrisAllen, Mr. William Henr...    1390
# 1         151290  Cumings, Mrs. John Bradley (Florence Briggs Th...     666
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalemale...   8184.67    161
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282347742237736PP 9549113...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         16498.1294  C85G6C103D56A6B78D33C52B28F33C23 C25 C27D10 D1...
#
# ...

# %%
g.mean(numeric_only=True)  # mean only nomeric value ka ho nokala jata hai
# Out:
#                index    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         445.018215  2.531876  30.626179  0.553734  0.329690  22.117887
# 1         443.665689  1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1 = df.groupby('Pclass')

# %%
g1.sum()
# Out:
#         PassengerId  Survived  \
# Pclass
# 1             99705       136
# 2             82056        87
# 3            215625       119
#
#                                                      Name  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991138031746311378311378819950PC 17601PC...  18177.4125
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# ...

# %%
g1.mean(numeric_only=True)
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max(numeric_only=True).T
# Out:
# Pclass              1      2       3
# PassengerId  890.0000  887.0  891.00
# Survived       1.0000    1.0    1.00
# Age           80.0000   70.0   74.00
# SibSp          3.0000    3.0    8.00
# Parch          4.0000    3.0    6.00
# Fare         512.3292   73.5   69.55

# %%
g1.max().transpose()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df5= df[['Name', 'Survived', 'Pclass']][0:5]

# %%
df6 = df[['Name',	'Survived',	'Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5,df6])  # concat is used to combine (concatenate) multiple DataFrames row-wise or column-wise.
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5,df6],axis=1)

# %%
df7.fillna('ayush')  # fillna khali place ko bharta hai
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                              ayush    ayush  ayush
# 6                                              ayush    ayush  ayush
# 7                                              ayush    ayush  ayush
# 8                                              ayush    ayush  ayush
# 9                                              ayush    ayush  ayush
#
#                                                 Name Survived Pclass
# 0                                              ayush    ayush  ayush
# 1                                              ayush    ayush  ayush
# ...

# %%
data1 = pd.DataFrame({
    'key1' : [1,2,4,5,6],
    'key2' : [4,5,6,7,8],
    'key3' : [3,4,5,6,6]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2 = pd.DataFrame({
    'key1' : [1,2,45,6,67],
    'key4' : [56,5,6,7,8],
    'key5' : [3,56,5,6,6]
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data1,data2)  # column me  common data ko only leta hai
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(data1,data2,how = 'outer', on = 'key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
pd.merge(data1,data2,how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                     index = ['a','b','c','d','e']
)

# %%
data2 = pd.DataFrame({'key11':[1,2,4,5,6],
                      'key22':[4,5,6,7,8],
                      'key33':[3,4,5,6,6]
},index=['a','b','h','i','j']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# j      6      8      6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1      4      3
# b   2.0   5.0   4.0      2      5      4
# h   NaN   NaN   NaN      4      6      5
# i   NaN   NaN   NaN      5      7      6
# j   NaN   NaN   NaN      6      8      6

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    5.0
# i   NaN   NaN   NaN    5.0    7.0    6.0
# j   NaN   NaN   NaN    6.0    8.0    6.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      4      6      5
# 3      1     4     3      5      7      6
# 4      1     4     3      6      8      6
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4      4      6      5
# 8      2     5     4      5      7      6
# 9      2     5     4      6      8      6
# 10     4     6     5      1      4      3
# 11     4     6     5      2      5      4
# 12     4     6     5      4      6      5
# 13     4     6     5      5      7      6
# 14     4     6     5      6      8      6
# 15     5     7     6      1      4      3
# 16     5     7     6      2      5      4
# 17     5     7     6      4      6      5
# 18     5     7     6      5      7      6
# 19     5     7     6      6      8      6
# 20     6     8     6      1      4      3
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
def euro_inr(x):
    return x*80

df['Fare_INR'] = df['Fare'].apply(euro_inr)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR  name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# ...

# %%
def cat_fare(x):
    if x<10 :
        return "cheap"
    elif x>=10 and x<20:
        return 'mid'
    else :
        return 'high'

# %%
df['car_fare'] = df['Fare'].apply(cat_fare)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...
